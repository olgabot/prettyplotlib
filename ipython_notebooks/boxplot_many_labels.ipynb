# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import prettyplotlib as ppl
import matplotlib as mpl

# Make random string labels
from pandas.util.testing import rands

np.random.seed(10)

ndatapoints = 10
nitems = 20

data = np.random.randn(ndatapoints, nitems)
labels = [rands(5) for i in range(nitems)]

# fig, ax = plt.subplots(figsize=(10, 4))
ppl.boxplot(data, xticklabels=labels)
fig.savefig('boxplot_prettyplotlib_many_labels.png')

# %%
import prettyplotlib as ppl
import matplotlib as mpl

# Make random string labels
from pandas.util.testing import rands

np.random.seed(10)

ndatapoints = 10
nitems = 10

data = np.random.randn(ndatapoints, nitems)
labels = [rands(5) for i in range(nitems)]

# fig, ax = plt.subplots(figsize=(10, 4))
ppl.boxplot(data, xticklabels=labels)
fig.savefig('boxplot_prettyplotlib_many_labels.png')

# %%
import prettyplotlib as ppl
import matplotlib as mpl

# Make random string labels
from pandas.util.testing import rands

np.random.seed(10)

ndatapoints = 10
nitems = 5

data = np.random.randn(ndatapoints, nitems)
labels = [rands(5) for i in range(nitems)]

# fig, ax = plt.subplots(figsize=(10, 4))
ppl.boxplot(data, xticklabels=labels)
fig.savefig('boxplot_prettyplotlib_many_labels.png')

# %% [raw]
# But if you have MANY items (`nitems = 50`), I suggest making your figure wider:

# %%
import prettyplotlib as ppl
import matplotlib as mpl

# Make random string labels
from pandas.util.testing import rands

np.random.seed(10)

ndatapoints = 10
nitems = 50

data = np.random.randn(ndatapoints, nitems)
labels = [rands(5) for i in range(nitems)]


figwidth = 20
figheight = 4
fig, ax = plt.subplots(figsize=(figwidth, figheight))
ppl.boxplot(data, xticklabels=labels)
fig.savefig('boxplot_prettyplotlib_many_labels.png')
