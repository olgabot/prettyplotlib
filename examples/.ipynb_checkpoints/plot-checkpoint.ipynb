# %% [markdown]
# ## `prettyplotlib.plot` Example
#
# The default matplotlib color cycle is not pretty to look at ... It was taken from MATLAB's color cycle. Need to do this example first because `prettyplotlib` changes the default color cycle to a nicer one, from [ColorBrewer](http://bl.ocks.org/mbostock/5577023)'s Set2.

# %%
import matplotlib.pyplot as mpl_plt
# Set the random seed for consistency
np.random.seed(12)

fig, ax = mpl_plt.subplots(1)

# Show the whole color range
for i in range(8):
    y = np.random.normal(size=1000).cumsum()
    ax.plot(y)
    
ax.set_title('prettyplotlib `plot` example\nshowing default matplotlib `plot`')
fig.savefig('plot_matplotlib_default.png')
fig.savefig('plot_matplotlib_default.pdf')

# %% [markdown]
# Yeah.. not nice

# %%
import prettyplotlib as ppl

# prettyplotlib imports 
from prettyplotlib import plt
from prettyplotlib import mpl
from prettyplotlib import brewer2mpl

# Set the random seed for consistency
np.random.seed(12)

fig, ax = plt.subplots(1)

# Show the whole color range
for i in range(8):
    y = np.random.normal(size=1000).cumsum()
    x = np.arange(1000)

    # For now, you need to specify both x and y :(
    # Still figuring out how to specify just one
    ppl.plot(ax, x, y)

fig.savefig('plot_prettyplotlib_default.png')
fig.savefig('plot_prettyplotlib_default.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-0bc9a40a589c> in <module>()
#      18     # For now, you need to specify both x and y :(
#      19     # Still figuring out how to specify just one
# ---> 20     ppl.plot(ax, x, y)
#      21
#      22 fig.savefig('plot_prettyplotlib_default.png')
#
# //anaconda/lib/python2.7/site-packages/prettyplotlib/__init__.pyc in plot(ax, x, y, **kwargs)
#     107
#     108     ax.plot(x, y, color=color, **kwargs)
# --> 109     remove_chartjunk(ax, ['top', 'right'])
#     110
#     111 def scatter(ax, x, y, **kwargs):
#
# //anaconda/lib/python2.7/site-packages/prettyplotlib/__init__.pyc in remove_chartjunk(ax, spines, grid, ticklabels)
#      60             ax.spines[spine].set_linewidth(0.5)
#      61             ax.spines[spine].set_color(almost_black)
# ---> 62             ax.spines[spine].set_tick_params(color=almost_black)
#      63     # Check that the axes are not log-scale. If they are, leave the ticks
#      64     # because otherwise people assume a linear scale.
#
# AttributeError: 'Spine' object has no attribute 'set_tick_params'

# %% [markdown]
# Now that's pretty nice!
#
# A few things happened here:
#
# 1. Default color cycle changed to the colors of ColorBrewer's Set2
# 3. Removed top and right axis lines
# 4. Ever-so-subtly changed the ticklabel and axis line colors from black (`#000000`) to almost black (`#262626`)
